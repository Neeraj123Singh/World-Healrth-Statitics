# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
handWash = pd.read_csv("C:\\Users\\user\\Desktop\\dataset\\basicHandWashing.csv")

# %%
handWash.head(10)
# Out:
#       Location                                          Indicator  Period  \
# 0  Afghanistan  Population with basic handwashing facilities a...    2017
# 1  Afghanistan  Population with basic handwashing facilities a...    2017
# 2  Afghanistan  Population with basic handwashing facilities a...    2017
# 3  Afghanistan  Population with basic handwashing facilities a...    2016
# 4  Afghanistan  Population with basic handwashing facilities a...    2016
# 5  Afghanistan  Population with basic handwashing facilities a...    2016
# 6  Afghanistan  Population with basic handwashing facilities a...    2015
# 7  Afghanistan  Population with basic handwashing facilities a...    2015
# 8  Afghanistan  Population with basic handwashing facilities a...    2015
# 9  Afghanistan  Population with basic handwashing facilities a...    2014
#
#     Dim1  First Tooltip
# 0  Total          37.75
# 1  Urban          63.58
# 2  Rural          29.02
# 3  Total          37.67
# 4  Urban          63.58
# 5  Rural          29.02
# 6  Total          37.59
# 7  Urban          63.58
# 8  Rural          29.02
# 9  Total          37.52

# %%
allCountries = handWash['Location'].unique().tolist()

# %%
def autoLabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2, height, '%d'%int(height), ha='center', va = 'bottom')

# %%
tempData = handWash[handWash['Period'] == 2017] 
tempData=tempData[tempData['Dim1']=='Urban']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[-50:]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Sanitization in %")
plt.title("Top 50 Contries in  Population with basic handwashing facilities at home (%) in Urban Area's in 2017")
plt.show()

# %%
tempData = handWash[handWash['Period'] == 2017] 
tempData=tempData[tempData['Dim1']=='Rural']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[-50:]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Sanitization in %")
plt.title("Top 50 Contries in  Population with basic handwashing facilities at home (%) in Rural Area's in 2017")
plt.show()

# %%
tempData = handWash[handWash['Period'] == 2017] 
tempData=tempData[tempData['Dim1']=='Total']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[-50:]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Sanitization in %")
plt.title("Top 50 Contries in  Population with basic handwashing facilities at home (%) in Both (Urban+Rural) Area's in 2017")
plt.show()

# %%
tempData = handWash[handWash['Period'] == 2017] 
tempData=tempData[tempData['Dim1']=='Urban']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[:50]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Sanitization in %")
plt.title("Bottom 50 Contries in  Population with basic handwashing facilities at home (%) in Urban Area's in 2017")
plt.show()

# %%
tempData = handWash[handWash['Period'] == 2017] 
tempData=tempData[tempData['Dim1']=='Rural']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[:50]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Sanitization in %")
plt.title("Bottom 50 Contries in  Population with basic handwashing facilities at home (%) in Rural Area's in 2017")
plt.show()

# %%
tempData = handWash[handWash['Period'] == 2017] 
tempData=tempData[tempData['Dim1']=='Total']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[:50]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Sanitization in %")
plt.title("Bottom 50 Contries in  Population with basic handwashing facilities at home (%) in Both(Urban+Rural) Area's in 2017")
plt.show()

# %%
tempData2017 = handWash[handWash['Period'] == 2017]
tempData2000 = handWash[handWash['Period'] == 2000]
tempData2017.reset_index(inplace=True)
tempData2000.reset_index(inplace=True)
tempData = tempData2017.join(tempData2000, lsuffix='_17', rsuffix='_00')
tempData['progress'] = tempData['First Tooltip_00'] - tempData['First Tooltip_17']
tempData = tempData[['Location_17', 'progress']].sort_values('progress', ascending=False)
tempDataTop = tempData[-50:]
tempDataBot = tempData[:50]

fig = plt.figure(figsize=(20,10))

ax1 = plt.subplot2grid((1,1), (0,0), rowspan=1, colspan=1)
rects1 = ax1.bar(tempDataTop['Location_17'], tempDataBot['progress'], color = 'green')
rects2 = ax1.bar(tempDataBot['Location_17'], tempDataTop['progress'], color = 'red')
for tick in ax1.get_xticklabels():
    tick.set_rotation(90)

plt.xlabel("Countries")
plt.ylabel("Progress")
plt.title("Progress of Different Countries ")
plt.show()
