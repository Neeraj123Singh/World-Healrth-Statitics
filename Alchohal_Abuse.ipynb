# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
alcholhalAbuse = pd.read_csv("C:\\Users\\user\\Desktop\\dataset\\alcoholSubstanceAbuse.csv")

# %%
alcholhalAbuse.head(10)
# Out:
#       Location  Period                                          Indicator  \
# 0  Afghanistan    2018  Total (recorded+unrecorded) alcohol per capita...
# 1  Afghanistan    2018  Total (recorded+unrecorded) alcohol per capita...
# 2  Afghanistan    2018  Total (recorded+unrecorded) alcohol per capita...
# 3  Afghanistan    2015  Total (recorded+unrecorded) alcohol per capita...
# 4  Afghanistan    2015  Total (recorded+unrecorded) alcohol per capita...
# 5  Afghanistan    2015  Total (recorded+unrecorded) alcohol per capita...
# 6  Afghanistan    2010  Total (recorded+unrecorded) alcohol per capita...
# 7  Afghanistan    2010  Total (recorded+unrecorded) alcohol per capita...
# 8  Afghanistan    2010  Total (recorded+unrecorded) alcohol per capita...
# 9      Albania    2018  Total (recorded+unrecorded) alcohol per capita...
#
#          Dim1  First Tooltip
# 0  Both sexes          0.210
# 1        Male          0.360
# 2      Female          0.055
# 3  Both sexes          0.210
# 4        Male          0.350
# 5      Female          0.054
# 6  Both sexes          0.210
# 7        Male          0.360
# 8      Female          0.054
# 9  Both sexes          7.170

# %%
allCountries = alcholhalAbuse['Location'].unique().tolist()

# %%
def compareCountries(countries):
    fig = plt.figure(figsize = (10,10))
    ax1 = plt.subplot2grid((1,1),(0,0))

    for country in countries:
        if country not in allCountries:
            print(f"Country {country} DO NOT EXIST ")
            return
        tempData = alcholhalAbuse[alcholhalAbuse['Location'] == country]
        tempData['Period'] = pd.to_datetime(tempData['Period'], format = '%Y')
        ax1.plot(tempData['Period'], tempData['First Tooltip'], label=country)
        
    for tick in ax1.get_xticklabels():
        tick.set_rotation(45)
    plt.grid()
    plt.legend()
    plt.xlabel("Year")
    plt.ylabel("Alcohol per caita income")
    plt.title("Total (recorded+unrecorded) alcohol per capita (15+) consumption")
    plt.show()

# %%
def autoLabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2, height, '%d'%int(height), ha='center', va = 'bottom')

# %%
tempData = alcholhalAbuse[alcholhalAbuse['Period'] == 2018] 
tempData=tempData[tempData['Dim1']=='Male']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[-20:]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Alcohal Abuse")
plt.title("Top 20 Contries in  Total (recorded+unrecorded) alcohol per capita (15+) consumption Male")
plt.show()

# %%
tempData = alcholhalAbuse[alcholhalAbuse['Period'] == 2018] 
tempData=tempData[tempData['Dim1']=='Female']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[-20:]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Alcohal Abuse")
plt.title("Top 20 Contries in  Total (recorded+unrecorded) alcohol per capita (15+) consumption Female")
plt.show()

# %%
tempData = alcholhalAbuse[alcholhalAbuse['Period'] == 2018] 
tempData=tempData[tempData['Dim1']=='Both sexes']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[-20:]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Alcohal Abuse")
plt.title("Top 20 Contries in  Total (recorded+unrecorded) alcohol per capita (15+) consumption Both Sexes")
plt.show()

# %%
tempData = alcholhalAbuse[alcholhalAbuse['Period'] == 2018] 
tempData=tempData[tempData['Dim1']=='Both sexes']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[:20]



fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Alchohal Abuse")
plt.title("Bottom 20   Total (recorded+unrecorded) alcohol per capita (15+) consumption Both Sexes")
plt.show()

# %%
tempData = alcholhalAbuse[alcholhalAbuse['Period'] == 2018] 
tempData=tempData[tempData['Dim1']=='Male']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[:20]



fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Alchohal Abuse")
plt.title("Bottom 20   Total (recorded+unrecorded) alcohol per capita (15+) consumption Male")
plt.show()

# %%
tempData = alcholhalAbuse[alcholhalAbuse['Period'] == 2018] 
tempData=tempData[tempData['Dim1']=='Female']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[:20]



fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Alchohal Abuse")
plt.title("Bottom 20   Total (recorded+unrecorded) alcohol per capita (15+) consumption Female")
plt.show()

# %%
tempData2018 = alcholhalAbuse[alcholhalAbuse['Period'] == 2018]
tempData2000 = alcholhalAbuse[alcholhalAbuse['Period'] == 2000]
tempData2018.reset_index(inplace=True)
tempData2000.reset_index(inplace=True)
tempData = tempData2018.join(tempData2000, lsuffix='_18', rsuffix='_00')
tempData['progress'] = tempData['First Tooltip_00'] - tempData['First Tooltip_18']
tempData = tempData[['Location_18', 'progress']].sort_values('progress', ascending=False)
tempDataTop = tempData[-50:]
tempDataBot = tempData[:50]

fig = plt.figure(figsize=(20,10))

ax1 = plt.subplot2grid((1,1), (0,0), rowspan=1, colspan=1)
rects1 = ax1.bar(tempDataTop['Location_18'], tempDataBot['progress'], color = '#92f779')
rects1 = ax1.bar(tempDataBot['Location_18'], tempDataTop['progress'], color = '#fc7272')
for tick in ax1.get_xticklabels():
    tick.set_rotation(90)

plt.xlabel("Countries")
plt.ylabel("Progress")
plt.title("Progress of Different Countries")
plt.show()

# %%
def lines(data):
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))

    probs = data[data['Dim1']=='Both sexes']['First Tooltip'].sort_values()
    least_keys, most_keys = probs[1:4], probs[-4:-1]
    least = data['Location'][least_keys.keys()]
    most = data['Location'][most_keys.keys()]
    freq = pd.DataFrame({'Least':least.reset_index(drop=True), 'Most':most.reset_index(drop=True)})

    for title in freq:
        for country in freq[title]:
            ax = axes[list(freq).index(title)][list(freq[title]).index(country)]
            df = data[data['Location']==country]

            both = df[df['Dim1']=='Both sexes']['First Tooltip']
            fema = df[df['Dim1']=='Male']['First Tooltip']
            male = df[df['Dim1']=='Female']['First Tooltip']
            years = np.unique(df['Period'])[::-1]

            ax.plot(years, both, label='Both sexes')
            ax.plot(years, fema, label='Females')
            ax.plot(years, male, label='Males')

            ax.set_title(title)
            ax.set_xlabel('Years in ' + country)
            ax.set_ylabel('Probability (%)')
            ax.legend()

    plt.suptitle(data['Indicator'].iloc[0])
    plt.show()

# %%
lines(alcholhalAbuse)
