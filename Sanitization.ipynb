# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sanitization = pd.read_csv("C:\\Users\\user\\Desktop\\dataset\\atLeastBasicSanitizationServices.csv")

# %%
sanitization.head(10)
# Out:
#       Location                                          Indicator  Period  \
# 0  Afghanistan  Population using at least basic sanitation ser...    2017
# 1  Afghanistan  Population using at least basic sanitation ser...    2017
# 2  Afghanistan  Population using at least basic sanitation ser...    2017
# 3  Afghanistan  Population using at least basic sanitation ser...    2016
# 4  Afghanistan  Population using at least basic sanitation ser...    2016
# 5  Afghanistan  Population using at least basic sanitation ser...    2016
# 6  Afghanistan  Population using at least basic sanitation ser...    2015
# 7  Afghanistan  Population using at least basic sanitation ser...    2015
# 8  Afghanistan  Population using at least basic sanitation ser...    2015
# 9  Afghanistan  Population using at least basic sanitation ser...    2014
#
#     Dim1  First Tooltip
# 0  Total          43.42
# 1  Urban          62.26
# 2  Rural          37.05
# 3  Total          42.05
# 4  Urban          59.92
# ...

# %%
allCountries = sanitization['Location'].unique().tolist()

# %%
def compareCountries(countries):
    fig = plt.figure(figsize = (10,10))
    ax1 = plt.subplot2grid((1,1),(0,0))

    for country in countries:
        if country not in allCountries:
            print(f"Country {country} DO NOT EXIST ")
            return
        tempData = sanitization[sanitization['Location'] == country]
        tempData['Period'] = pd.to_datetime(tempData['Period'], format = '%Y')
        ax1.plot(tempData['Period'], tempData['First Tooltip'], label=country)
        
    for tick in ax1.get_xticklabels():
        tick.set_rotation(45)
    plt.grid()
    plt.legend()
    plt.xlabel("Year")
    plt.ylabel("Sanitization in %")
    plt.title("Population using at least basic sanitation services (%) ")
    plt.show()

# %%
def autoLabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2, height, '%d'%int(height), ha='center', va = 'bottom')

# %%
tempData = sanitization[sanitization['Period'] == 2017] 
tempData=tempData[tempData['Dim1']=='Urban']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[-50:]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Sanitization in %")
plt.title("Top 50 Contries in  Population using at least basic sanitation services (%) in Urban Area's in 2017")
plt.show()

# %%
tempData = sanitization[sanitization['Period'] == 2017] 
tempData=tempData[tempData['Dim1']=='Rural']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[-50:]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Sanitization in %")
plt.title("Top 50 Contries in  Population using at least basic sanitation services (%) in Rural Area's in 2017")
plt.show()

# %%
tempData = sanitization[sanitization['Period'] == 2017] 
tempData=tempData[tempData['Dim1']=='Total']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[-50:]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "blue")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Sanitization in %")
plt.title("Top 50 Contries in  Population using at least basic sanitation services (%) in Both(Urban + Rural) Area's in 2017")
plt.show()

# %%
tempData = sanitization[sanitization['Period'] == 2017] 
tempData=tempData[tempData['Dim1']=='Urban']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[:50]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Sanitization in %")
plt.title("Bottom 50 Contries in  Population using at least basic sanitation services (%) in Urban Area's in 2017")
plt.show()

# %%
tempData = sanitization[sanitization['Period'] == 2017] 
tempData=tempData[tempData['Dim1']=='Rural']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[:50]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Sanitization in %")
plt.title("Bottom 50 Contries in  Population using at least basic sanitation services (%) in Rural Area's in 2017")
plt.show()

# %%
tempData = sanitization[sanitization['Period'] == 2017] 
tempData=tempData[tempData['Dim1']=='Total']
tempData.sort_values('First Tooltip', inplace=True)
tempDataBot = tempData[:50]
fig = plt.figure(figsize=(20,6))
ax = plt.subplot2grid((1,1),(0,0))
rects = ax.bar(tempDataBot['Location'], tempDataBot['First Tooltip'], color = "#fc7272")
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
autoLabel(rects)
plt.xlabel("Countries")
plt.ylabel("Sanitization in %")
plt.title("Bottom 50 Contries in  Population using at least basic sanitation services (%) in Both( Urban + Rural )Area's in 2017")
plt.show()

# %%
tempData2017 = sanitization[sanitization['Period'] == 2017]
tempData2000 = sanitization[sanitization['Period'] == 2000]
tempData2017.reset_index(inplace=True)
tempData2000.reset_index(inplace=True)
tempData = tempData2017.join(tempData2000, lsuffix='_17', rsuffix='_00')
tempData['progress'] = tempData['First Tooltip_00'] - tempData['First Tooltip_17']
tempData = tempData[['Location_17', 'progress']].sort_values('progress', ascending=False)
tempDataTop = tempData[-50:]
tempDataBot = tempData[:50]

fig = plt.figure(figsize=(20,10))

ax1 = plt.subplot2grid((1,1), (0,0), rowspan=1, colspan=1)
rects1 = ax1.bar(tempDataTop['Location_17'], tempDataBot['progress'], color = '#92f779')
rects1 = ax1.bar(tempDataBot['Location_17'], tempDataTop['progress'], color = '#fc7272')
for tick in ax1.get_xticklabels():
    tick.set_rotation(90)

plt.xlabel("Countries")
plt.ylabel("Progress")
plt.title("Progress of Different Countries")
plt.show()
